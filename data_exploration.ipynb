# %% [markdown]
# # Examining Collinearity Within the Data

# %%
import pandas as pd
import numpy as np

from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('train.csv')
X = df.drop(['outcome'], axis=1)

# %%
numeric_columns = X.select_dtypes(include=['number']).columns

categorical_columns = list(set(X.columns) - set(numeric_columns))

# %%
numeric_pipe = Pipeline([('imputer', SimpleImputer(strategy='median'))])
categorical_pipe = Pipeline([('imputer', SimpleImputer(strategy='constant', fill_value='missing')), ('ohe', OneHotEncoder(sparse=False))])

num_X = pd.DataFrame(numeric_pipe.fit_transform(X[numeric_columns]), columns=numeric_columns)

cat_X = categorical_pipe.fit_transform(X[categorical_columns])
onehot_col_names = categorical_pipe.named_steps['ohe'].get_feature_names_out(input_features=categorical_columns)
cat_X = pd.DataFrame(cat_X, columns=onehot_col_names)

X = pd.merge(num_X, cat_X, left_index=True, right_index=True)

# %%
# calculating VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

pd.set_option('display.max_rows', None)
print(vif_data)
pd.reset_option('display.max_rows')
# Out:
# /Users/r.lebrasseur/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /Users/r.lebrasseur/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#                                    feature           VIF
# 0                                     r_kd  1.714326e+00
# 1                                r_sub.att  1.664085e+00
# 2                                   r_rev.  1.284558e+00
# 3                                 r_ctrl_s  5.152235e+00
# 4                        r_sig_str_percent  1.698390e+01
# 5                            r_sig_str_att           inf
# 6                      r_total_str_percent  8.610538e+00
# 7                          r_total_str_att  2.138108e+01
# 8                             r_td_percent  1.285973e+00
# 9                                 r_td_att  2.330423e+00
# 10                          r_head_percent  8.989691e+00
# 11                              r_head_att           inf
# 12                          r_body_percent  1.643944e+00
# 13                              r_body_att           inf
# 14                           r_leg_percent  1.345170e+00
# 15                               r_leg_att           inf
# 16                      r_distance_percent  3.430235e+00
# 17                          r_distance_att           inf
# 18                        r_clinch_percent  1.400352e+00
# 19                            r_clinch_att           inf
# 20                        r_ground_percent  1.404943e+00
# 21                            r_ground_att           inf
# 22                            r_avg_time_s  4.937389e+00
# 23                                  r_wins           inf
# 24                                r_losses           inf
# 25                                 r_draws  1.116575e+00
# 26                            r_win_streak           inf
# 27                           r_loss_streak           inf
# 28                    r_longest_win_streak           inf
# 29                   r_percent_title_bouts  1.799924e+00
# 30                 r_percent_win_by_ko/tko  3.637441e+00
# 31                    r_percent_win_by_sub  2.737105e+00
# 32                    r_percent_win_by_dec  3.222964e+00
# 33        r_percent_win_by_doctor_stoppage  1.122532e+00
# 34                r_percent_loss_by_ko/tko  2.027290e+00
# 35                   r_percent_loss_by_sub  1.744554e+00
# 36                   r_percent_loss_by_dec  2.578562e+00
# 37       r_percent_loss_by_doctor_stoppage  1.073303e+00
# 38                                    b_kd  1.338776e+00
# 39                               b_sub.att  1.278304e+00
# 40                                  b_rev.  1.281740e+00
# 41                                b_ctrl_s  4.192612e+00
# 42                       b_sig_str_percent  1.197828e+01
# 43                           b_sig_str_att           inf
# 44                     b_total_str_percent  6.630742e+00
# 45                         b_total_str_att  1.954364e+01
# 46                            b_td_percent  1.241162e+00
# 47                                b_td_att  2.200824e+00
# 48                          b_head_percent  5.281364e+00
# 49                              b_head_att           inf
# 50                          b_body_percent  1.514066e+00
# 51                              b_body_att           inf
# 52                           b_leg_percent  1.313478e+00
# 53                               b_leg_att           inf
# 54                      b_distance_percent  3.463156e+00
# 55                          b_distance_att           inf
# 56                        b_clinch_percent  1.403945e+00
# 57                            b_clinch_att           inf
# 58                        b_ground_percent  1.368196e+00
# 59                            b_ground_att           inf
# 60                            b_avg_time_s  3.121217e+00
# 61                                  b_wins           NaN
# 62                                b_losses           NaN
# 63                                 b_draws           NaN
# 64                            b_win_streak           NaN
# 65                           b_loss_streak           NaN
# 66                    b_longest_win_streak           NaN
# 67                   b_percent_title_bouts           NaN
# 68                 b_percent_win_by_ko/tko           NaN
# 69                    b_percent_win_by_sub           NaN
# 70                    b_percent_win_by_dec           NaN
# 71        b_percent_win_by_doctor_stoppage           NaN
# 72                b_percent_loss_by_ko/tko           NaN
# 73                   b_percent_loss_by_sub           NaN
# 74                   b_percent_loss_by_dec           NaN
# 75       b_percent_loss_by_doctor_stoppage           NaN
# 76                                    date  5.151098e+00
# 77                                r_height  6.300618e+00
# 78                                 r_reach  5.150347e+00
# 79                                   r_dob  3.058892e+00
# 80                                b_height  5.302035e+00
# 81                                 b_reach  4.192430e+00
# 82                                   b_dob  2.651245e+00
# 83                weightclass_Bantamweight           inf
# 84                weightclass_Catch Weight           inf
# 85               weightclass_Featherweight           inf
# 86                   weightclass_Flyweight           inf
# 87                 weightclass_Heavyweight           inf
# 88           weightclass_Light Heavyweight           inf
# 89                 weightclass_Lightweight           inf
# 90                weightclass_Middleweight           inf
# 91                weightclass_Welterweight           inf
# 92   weightclass_Women's Bantamweight Bout           inf
# 93       weightclass_Women's Featherweight           inf
# 94      weightclass_Women's Flyweight Bout           inf
# 95         weightclass_Women's Strawweight           inf
# 96                             title_False           inf
# 97                              title_True           inf
# 98               time_format_3 Rnd (5-5-5)           inf
# 99        time_format_3 Rnd + OT (5-5-5-5)           inf
# 100          time_format_5 Rnd (5-5-5-5-5)           inf
# 101                            b_stance_--  9.007199e+15
# 102                   b_stance_Open Stance           inf
# 103                      b_stance_Orthodox           inf
# 104                      b_stance_Sideways           inf
# 105                      b_stance_Southpaw           inf
# 106                        b_stance_Switch           inf
# 107                            r_stance_--           inf
# 108                   r_stance_Open Stance           inf
# 109                      r_stance_Orthodox           inf
# 110                      r_stance_Southpaw           inf
# 111                        r_stance_Switch           inf

# %% [markdown]
# # Examining Favourite Win Rate by Year

# %%
df = pd.read_csv('train.csv')
df['date'] = pd.to_datetime(df['date']*10**11)
df['year'] = df['date'].dt.year

fav_win_rates = df[df['outcome'] == 'R'].groupby('year').size()/df.groupby('year').size()

# %%
fav_win_rates
# Out:
# year
# 2001    1.000000
# 2002    1.000000
# 2003    1.000000
# 2004    1.000000
# 2005    1.000000
# 2006    1.000000
# 2007    1.000000
# 2008    1.000000
# 2009    1.000000
# 2010    0.612000
# 2011    0.600671
# 2012    0.622754
# 2013    0.593668
# 2014    0.631579
# 2015    0.571121
# 2016    0.593429
# 2017    0.556054
# 2018    0.541578
# 2019    0.572835
# 2020    0.612108
# 2021    0.567460
# 2022    0.595285
# 2023    0.532319
# dtype: float64

# %%
df[df['outcome'] == 'B']
# Out:
#      outcome        weightclass    time_format  title      r_kd  r_sub.att  \
# 1          B        Lightweight  3 Rnd (5-5-5)  False  0.166667   0.000000
# 2          B       Welterweight  3 Rnd (5-5-5)  False  0.571429   0.285714
# 4          B        Lightweight  3 Rnd (5-5-5)  False  1.000000   0.000000
# 5          B       Middleweight  3 Rnd (5-5-5)  False  1.000000   0.000000
# 6          B       Welterweight  3 Rnd (5-5-5)  False  0.055556   0.611111
# ...      ...                ...            ...    ...       ...        ...
# 5798       B  Light Heavyweight  3 Rnd (5-5-5)  False  0.000000   2.000000
# 5800       B  Light Heavyweight  3 Rnd (5-5-5)  False  0.636364   0.090909
# 5805       B  Light Heavyweight  3 Rnd (5-5-5)  False  0.000000   0.666667
# 5806       B        Lightweight  3 Rnd (5-5-5)  False  0.333333   0.000000
# 5810       B  Light Heavyweight  3 Rnd (5-5-5)  False  0.000000   1.333333
#
#         r_rev.    r_ctrl_s  r_sig_str_percent  r_sig_str_att  ...       date  \
# 1     0.000000  195.666667           0.426600     132.833333  ... 2023-07-01
# 2     0.214286  132.500000           0.502677     106.714286  ... 2023-07-01
# 4     0.000000   47.000000           0.693878      49.000000  ... 2023-07-01
# 5     0.000000    1.000000           0.488889      45.000000  ... 2023-07-01
# 6     0.111111  298.555556           0.422748     110.388889  ... 2023-07-01
# ...        ...         ...                ...            ...  ...        ...
# 5798  0.000000  359.000000           0.428571      35.000000  ... 2010-03-27
# 5800  0.000000   94.363636           0.549593      55.909091  ... 2010-03-21
# 5805  0.000000   29.666667           0.273649      98.666667  ... 2010-03-21
# 5806  0.000000   89.666667           0.482353      28.333333  ... 2010-03-21
# 5810  0.333333  126.000000           0.433180      36.166667  ... 2010-03-21
#
#       r_height  r_reach  r_stance      r_dob  b_height  b_reach  b_stance  \
# 1         70.0     74.0  Orthodox  6655392.0      70.0     72.0    Switch
# 2         71.0     76.0  Orthodox  5020704.0      72.0     79.0  Orthodox
# 4         68.0     71.0  Orthodox  8201088.0      71.0     73.0  Southpaw
# 5         70.0     72.0  Orthodox  7208352.0      77.0     76.0  Orthodox
# 6         69.0     77.0  Orthodox  7155648.0      72.0     74.0  Orthodox
# ...        ...      ...       ...        ...       ...      ...       ...
# 5798      69.0     72.0    Switch  3751488.0      75.0     75.0  Orthodox
# 5800      75.0     78.0  Orthodox  2452896.0      76.0     84.0  Orthodox
# 5805      74.0     77.0  Orthodox  3317760.0      72.0     74.0  Orthodox
# 5806      70.0     70.0  Orthodox  2710368.0      70.0     71.0  Orthodox
# 5810      75.0     76.0  Orthodox  2435616.0      71.0     71.0  Orthodox
#
#           b_dob  year
# 1     7617024.0  2023
# 2     9301824.0  2023
# 4     8192448.0  2023
# 5     7536672.0  2023
# 6     6860160.0  2023
# ...         ...   ...
# 5798  3843072.0  2010
# 5800  5536512.0  2010
# 5805   317952.0  2010
# 5806  4535136.0  2010
# 5810  1739232.0  2010
#
# [2425 rows x 90 columns]

# %% [markdown]
# Before 2010-03-21, the data shows the winner of each fight as being in the red corner. This is not the case in actuality. See Matt Serra VS Georges St. Pierre.
#
# Because of this, I shouldn't use R, B to set the baseline.
#
# One option is to calculate the baseline based on results after this is changed.
#
# (This may be why date is such an important feature in XGBoost.)

# %%
modern_df = df[df['date'] >= pd.to_datetime('2010-03-21')].copy()
y = pd.get_dummies(modern_df['outcome'], drop_first=True)
y = np.ravel(y).reshape((-1,))

fav_win_rate_modern = sum(y)/len(y)
fav_win_rate_modern
# Out:
# 0.5826880055067974

# %% [markdown]
# The win rate after 2010 is seen above
